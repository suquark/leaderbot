# %%
import leaderbot as lb
data = lb.data.load()

#data['Y'][:, -1] = 0

# model = lb.models.BradleyTerryScaled(data)
#model = lb.models.RaoKupper(data, n_tie_factors=0)
# model = lb.models.RaoKupperScaledR(data, n_tie_factors=1)  # best KPCA with n_tie_factor=1
#model = lb.models.RaoKupperScaledRIJ(data, n_tie_factors=1)
# model = lb.models.DavidsonScaled(data, n_tie_factors=2)
#model = lb.models.DavidsonScaledR(data, n_tie_factors=1)
# model = lb.models.DavidsonScaledRIJ(data, n_tie_factors=1)

#model = lb.models.DavidsonScaled(data, n_tie_factors=1)
#model = lb.models.DavidsonFactor(data, n_cov_factors=3, n_tie_factors=3)
model = lb.models.DavidsonScaled(data, n_tie_factors=0)
# model = lb.models.Davidson(data)
#model = lb.models.RaoKupperFactor(data, n_factors=3)
model.train() #method='L-BFGS-B')

latex = False
save = False

# %%
import pickle
import leaderbot as lb

filename = '../benchmark/models_train_full.pkl'
# filename = '../benchmark/models_train_full_both_ties.pkl'
#filename = '../benchmark/models_train_split.pkl'
with open(filename, 'rb') as f:
    results = pickle.load(f)

models = results['models']
test_data = results['test_data']

model = models[22]

# %%
latex = True
save = True

# %%
loss_const = model.loss(return_jac=False, constraint=True)
loss = model.loss(return_jac=False, constraint=False)
const = loss_const - loss
print(loss)
print(const)
# Out:
# 1.005528024279038
# 1.1561163359985471e-08

# %%
import numpy as np
n = model.n_agents
k = model.n_cov_factors
t = model.n_tie_factors
M = model.param[n * (2):n * (2 + k)].reshape(n, k)

print(k)
print(t)
print(np.sum(M, axis=0))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 import numpy as np
#       2 n = model.n_agents
# ----> 3 k = model.n_cov_factors
#       4 t = model.n_tie_factors
#       5 M = model.param[n * (2):n * (2 + k)].reshape(n, k)
#
# AttributeError: 'DavidsonScaled' object has no attribute 'n_cov_factors'

# %%
M
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 M
#
# NameError: name 'M' is not defined

# %%
model.leaderboard(max_rank=None, plot=True, latex=latex, save=save)
# Out:
# +---------------------------+--------+--------+---------------+---------------+
# |                           |        |    num |   observed    |   predicted   |
# | rnk  agent                |  score |  match | win loss  tie | win loss  tie |
# +---------------------------+--------+--------+---------------+---------------+
# |   1. chatgpt-4o-latest    | +0.141 |  10599 | 53%  23%  24% | 53%  23%  24% |
# |   2. gemini-1.5-pro-ex... | +0.135 |  13749 | 51%  26%  23% | 51%  26%  23% |
# |   3. gpt-4o-2024-05-13    | +0.127 |  61251 | 51%  26%  23% | 51%  26%  23% |
# |   4. gpt-4o-mini-2024-... | +0.123 |  12177 | 46%  29%  25% | 46%  29%  25% |
# |   5. claude-3-5-sonnet... | +0.123 |  37641 | 47%  30%  22% | 47%  30%  22% |
# |   6. gemini-advanced-0514 | +0.121 |  44241 | 49%  29%  22% | 49%  29%  22% |
# |   7. llama-3.1-405b-in... | +0.119 |  11967 | 46%  31%  23% | 46%  31%  23% |
# |   8. gpt-4o-2024-08-06    | +0.118 |   6758 | 44%  31%  25% | 44%  31%  25% |
# |   9. gemini-1.5-pro-ap... | +0.117 |  52409 | 47%  31%  22% | 47%  31%  22% |
# |  10. gemini-1.5-pro-ap... | +0.114 |  46485 | 52%  28%  20% | 52%  28%  20% |
# |  11. athene-70b-0725      | +0.113 |   7987 | 44%  34%  22% | 44%  34%  22% |
# |  12. gpt-4-turbo-2024-... | +0.112 |  68949 | 48%  28%  24% | 48%  28%  24% |
# |  13. mistral-large-2407   | +0.110 |   9165 | 40%  35%  25% | 40%  35%  25% |
# |  14. llama-3.1-70b-ins... | +0.109 |   9078 | 41%  37%  23% | 41%  37%  23% |
# |  15. claude-3-opus-202... | +0.108 | 120481 | 49%  30%  21% | 49%  30%  21% |
# |  16. gpt-4-1106-preview   | +0.107 |  76821 | 53%  25%  22% | 53%  25%  22% |
# |  17. yi-large-preview     | +0.103 |  37791 | 45%  33%  22% | 45%  33%  22% |
# |  18. gpt-4-0125-preview   | +0.103 |  74202 | 49%  28%  23% | 49%  28%  23% |
# |  19. gemini-1.5-flash-... | +0.098 |  44256 | 43%  36%  22% | 43%  36%  22% |
# |  20. reka-core-20240722   | +0.098 |   5440 | 39%  39%  22% | 39%  39%  22% |
# |  21. deepseek-coder-v2... | +0.095 |   2779 | 34%  43%  24% | 33%  42%  24% |
# |  22. gemma-2-27b-it       | +0.091 |  17994 | 38%  38%  24% | 38%  38%  24% |
# |  23. deepseek-v2-api-0628 | +0.089 |  12328 | 37%  39%  24% | 37%  39%  24% |
# |  24. yi-large             | +0.088 |  12475 | 39%  37%  24% | 39%  37%  24% |
# |  25. llama-3-70b-instruct | +0.085 | 118855 | 42%  36%  22% | 42%  36%  22% |
# |  26. bard-jan-24-gemin... | +0.085 |   9774 | 53%  31%  15% | 53%  31%  15% |
# |  27. nemotron-4-340b-i... | +0.085 |  14791 | 39%  38%  23% | 39%  38%  23% |
# |  28. glm-4-0520           | +0.084 |   7843 | 39%  38%  23% | 39%  38%  23% |
# |  29. reka-flash-20240722  | +0.082 |   4738 | 35%  43%  22% | 35%  43%  22% |
# |  30. claude-3-sonnet-2... | +0.080 |  91867 | 43%  36%  21% | 43%  36%  21% |
# |  31. reka-core-20240501   | +0.079 |  45407 | 39%  38%  23% | 39%  38%  23% |
# |  32. command-r-plus       | +0.074 |  59317 | 39%  39%  22% | 39%  39%  22% |
# |  33. glm-4-0116           | +0.074 |   5786 | 35%  43%  22% | 35%  42%  22% |
# |  34. gemma-2-9b-it        | +0.071 |  18364 | 33%  44%  23% | 33%  44%  23% |
# |  35. qwen-max-0428        | +0.071 |  21072 | 35%  41%  24% | 35%  41%  24% |
# |  36. qwen2-72b-instruct   | +0.070 |  22732 | 37%  41%  22% | 37%  41%  22% |
# |  37. gpt-4-0314           | +0.068 |  45204 | 45%  33%  22% | 45%  33%  22% |
# |  38. claude-3-haiku-20... | +0.067 |  76439 | 41%  39%  21% | 41%  39%  21% |
# |  39. deepseek-coder-v2    | +0.062 |  11073 | 35%  45%  21% | 34%  45%  21% |
# |  40. reka-flash-previe... | +0.060 |  13068 | 31%  48%  21% | 31%  48%  21% |
# |  41. qwen1.5-110b-chat    | +0.053 |  20495 | 33%  44%  23% | 33%  44%  23% |
# |  42. yi-1.5-34b-chat      | +0.052 |  15993 | 33%  47%  20% | 33%  47%  20% |
# |  43. gpt-4-0613           | +0.052 |  70427 | 37%  41%  22% | 37%  41%  22% |
# |  44. llama-3.1-8b-inst... | +0.052 |   8079 | 27%  54%  19% | 27%  54%  19% |
# | 112. mistral-7b-instruct  | -0.091 |   6735 | 30%  55%  15% | 30%  55%  15% |
# | 113. koala-13b            | -0.105 |   5018 | 40%  46%  14% | 40%  46%  14% |
# | 114. olmo-7b-instruct     | -0.115 |   4260 | 21%  68%  11% | 21%  68%  11% |
# | 115. qwen1.5-4b-chat      | -0.141 |   5825 | 18%  69%  13% | 18%  69%  12% |
# | 116. gpt4all-13b-snoozy   | -0.143 |   1277 | 29%  60%  12% | 28%  60%  12% |
# | 117. gemma-1.1-2b-it      | -0.155 |   7587 | 16%  71%  13% | 16%  71%  13% |
# | 118. chatglm3-6b          | -0.157 |   3309 | 20%  68%  13% | 19%  68%  13% |
# | 119. mpt-7b-chat          | -0.160 |   2565 | 31%  57%  12% | 30%  58%  12% |
# | 120. RWKV-4-Raven-14B     | -0.164 |   3692 | 30%  59%  11% | 30%  59%  11% |
# | 121. gemma-2b-it          | -0.173 |   3752 | 19%  70%  11% | 19%  70%  11% |
# | 122. alpaca-13b           | -0.181 |   3512 | 34%  57%  10% | 34%  57%  10% |
# | 123. oasst-pythia-12b     | -0.183 |   4090 | 30%  59%  11% | 30%  59%  11% |
# | 124. fastchat-t5-3b       | -0.225 |   2749 | 25%  64%  10% | 25%  64%  10% |
# | 125. chatglm-6b           | -0.227 |   2967 | 29%  60%  11% | 29%  60%  11% |
# | 126. chatglm2-6b          | -0.241 |   1963 | 19%  69%  12% | 19%  69%  12% |
# | 127. stablelm-tuned-al... | -0.268 |   2398 | 24%  67%   9% | 24%  67%   9% |
# | 128. dolly-v2-12b         | -0.284 |   2453 | 22%  72%   6% | 22%  72%   6% |
# | 129. llama-13b            | -0.336 |   1693 | 21%  71%   8% | 21%  71%   8% |
# +---------------------------+--------+--------+---------------+---------------+
# Plot saved to "/home/sia/work/github/arenaranking/notebooks/rank.svg".
# Plot saved to "/home/sia/work/github/arenaranking/notebooks/rank.pdf".

# %%
# %matplotlib tk
#%matplotlib inline
model.visualize(max_rank=40, method='kpca', dim='3d', latex=latex, save=save)
# Out:
# Plot saved to "/home/sia/work/github/arenaranking/notebooks/visualization.svg".
# Plot saved to "/home/sia/work/github/arenaranking/notebooks/visualization.pdf".

# %%
# %matplotlib tk
model.plot_scores(max_rank=50, horizontal=False, latex=latex, save=save)
# Out:
# Plot saved to "/home/sia/work/github/arenaranking/notebooks/scores.svg".
# Plot saved to "/home/sia/work/github/arenaranking/notebooks/scores.pdf".

# %%
model.match_matrix(max_rank=30, density=True, source='both',
                   latex=latex, save=save, horizontal=False,
                   win_range=[0.2, 0.6], tie_range=[0.15, 0.4])
# Out:
# Plot saved to "/home/sia/work/github/arenaranking/notebooks/match_matrix.svg".
# Plot saved to "/home/sia/work/github/arenaranking/notebooks/match_matrix.pdf".

# %%
model.match_matrix(max_rank=20, density=False, source='both',
                   latex=latex, save=save, horizontal=True,
                   win_range=[0, 3000], tie_range=[0, 1500])
# Out:
# Plot saved to "/home/sia/work/github/arenaranking/notebooks/match_matrix.svg".
# Plot saved to "/home/sia/work/github/arenaranking/notebooks/match_matrix.pdf".

# %%
y = data['Y']

a = y.sum()
b = y.sum(axis=0)

print(b[-1] / a)
# Out:
# 0.2044522311337633
